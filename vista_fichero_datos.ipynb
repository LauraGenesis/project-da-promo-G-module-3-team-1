# %%
import pandas as pd

import numpy as np

pd.set_option('display.max_columns', None)

# %%
data = pd.read_csv("Files/HR RAW DATA.csv",index_col = 0)

data
# Out:
#      Age Attrition BusinessTravel DailyRate                Department  \
# 0     51        No            NaN    684,0$                       NaN
# 1     52        No            NaN    699,0$                       NaN
# 2     42        No  travel_rarely    532,0$   Research & Development
# 3     47        No  travel_rarely    359,0$                       NaN
# 4     46        No            NaN   1319,0$                       NaN
# ...   ..       ...            ...       ...                       ...
# 1609  36       Yes  travel_rarely    530,0$                       NaN
# 1610  45        No     non-travel    805,0$                       NaN
# 1611  39        No  travel_rarely    903,0$                       NaN
# 1612  36        No     non-travel   1229,0$                       NaN
# 1613  46        No            NaN    566,0$                       NaN
#
#       DistanceFromHome  Education    EducationField  employeecount  \
# ...

# %%
data[['DailyRate', 'MonthlyRate']]
# Out:
#      DailyRate  MonthlyRate
# 0       684,0$         6462
# 1       699,0$         5678
# 2       532,0$         4933
# 3       359,0$        26703
# 4      1319,0$         7739
# ...        ...          ...
# 1609    530,0$         5518
# 1610    805,0$        23163
# 1611    903,0$         2560
# 1612   1229,0$        25952
# 1613    566,0$        24208
#
# [1614 rows x 2 columns]

# %%
data_ma_per = data.loc[:,'MaritalStatus':'PerformanceRating']

# %%
data_ma_per
# Out:
#      MaritalStatus  MonthlyIncome  MonthlyRate  NUMCOMPANIESWORKED Over18  \
# 0              NaN        19537.0         6462                   7      y
# 1              NaN        19999.0         5678                   0    NaN
# 2          married        19232.0         4933                   1    NaN
# 3          married        17169.0        26703                   3      y
# 4         divorced            NaN         7739                   2      y
# ...            ...            ...          ...                 ...    ...
# 1609       married        10325.0         5518                   1      y
# 1610           NaN         4447.0        23163                   1    NaN
# 1611        single            NaN         2560                   0    NaN
# 1612      divorced            NaN        25952                   4    NaN
# 1613           NaN        10845.0        24208                   6      y
#
#      OverTime  PercentSalaryHike PerformanceRating
# ...

# %%
data_ma_per.duplicated().sum()
# Out:
# 138

# %%
data_ma_per.isnull().sum()
# Out:
# MaritalStatus         651
# MonthlyIncome         843
# MonthlyRate             0
# NUMCOMPANIESWORKED      0
# Over18                901
# OverTime              676
# PercentSalaryHike       0
# PerformanceRating     195
# dtype: int64

# %%
data_ma_per.notnull().sum()
# Out:
# MaritalStatus          963
# MonthlyIncome          771
# MonthlyRate           1614
# NUMCOMPANIESWORKED    1614
# Over18                 713
# OverTime               938
# PercentSalaryHike     1614
# PerformanceRating     1419
# dtype: int64

# %%
data_ma_per.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1614 entries, 0 to 1613
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   MaritalStatus       963 non-null    object
#  1   MonthlyIncome       771 non-null    object
#  2   MonthlyRate         1614 non-null   int64
#  3   NUMCOMPANIESWORKED  1614 non-null   int64
#  4   Over18              713 non-null    object
#  5   OverTime            938 non-null    object
#  6   PercentSalaryHike   1614 non-null   int64
#  7   PerformanceRating   1419 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 113.5+ KB

# %%
data_ma_per.describe().T
# Out:
#                      count          mean          std     min     25%  \
# MonthlyRate         1614.0  14284.495663  7110.414585  2094.0  8001.0
# NUMCOMPANIESWORKED  1614.0      2.673482     2.506152     0.0     1.0
# PercentSalaryHike   1614.0     15.165428     3.648610    11.0    12.0
#
#                         50%      75%      max
# MonthlyRate         14248.5  20364.0  26999.0
# NUMCOMPANIESWORKED      2.0      4.0      9.0
# PercentSalaryHike      14.0     18.0     25.0

# %%
for columna in data.columns:
    if data[columna].dtype == "object":
        data[columna] = data[columna].str.lower()

# %%
data
# Out:
#      Age Attrition BusinessTravel DailyRate                Department  \
# 0     51        no            NaN    684,0$                       NaN
# 1     52        no            NaN    699,0$                       NaN
# 2     42        no  travel_rarely    532,0$   research & development
# 3     47        no  travel_rarely    359,0$                       NaN
# 4     46        no            NaN   1319,0$                       NaN
# ...   ..       ...            ...       ...                       ...
# 1609  36       yes  travel_rarely    530,0$                       NaN
# 1610  45        no     non-travel    805,0$                       NaN
# 1611  39        no  travel_rarely    903,0$                       NaN
# 1612  36        no     non-travel   1229,0$                       NaN
# 1613  46        no            NaN    566,0$                       NaN
#
#       DistanceFromHome  Education    EducationField  employeecount  \
# ...

# %% [markdown]
# **MARITAL STATUS**

# %%
MaritalStatus = data['MaritalStatus']

# %%
for idx, valor in enumerate(data['MaritalStatus']):
    if valor == 'marreid':
        data.loc[idx, 'MaritalStatus'] = 'married'
        print('cambiando a Married')
    else:
        pass
# Out:
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married

# %%
MaritalStatus.sample(10)
# Out:
# 1063     married
# 393     divorced
# 687      married
# 1455      single
# 140       single
# 1317     married
# 341       single
# 347     divorced
# 1557         NaN
# 1117         NaN
# Name: MaritalStatus, dtype: object

# %%
MaritalStatus_mal = data[(data['MaritalStatus'] != 'married') & (data['MaritalStatus'] != 'divorced') & (data['MaritalStatus'] != 'single') & (data['MaritalStatus'].notna())]['MaritalStatus']

# %%
len(MaritalStatus_mal)
# Out:
# 35

# %%
MaritalStatus_mal.sample(10)
# Out:
# 1065    marreid
# 1072    marreid
# 871     marreid
# 693     marreid
# 415     marreid
# 1504    marreid
# 1027    marreid
# 977     marreid
# 152     marreid
# 275     marreid
# Name: MaritalStatus, dtype: object

# %%
for idx, valor in enumerate(data['MaritalStatus']):
    if valor == 'marreid':
        data.loc[idx, 'MaritalStatus'] = 'married'
        print('cambiando a Married')
    else:
        pass
# Out:
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married
# cambiando a Married

# %%
MaritalStatus_mal = data[(data['MaritalStatus'] != 'married') & (data['MaritalStatus'] != 'divorced') & (data['MaritalStatus'] != 'single') & (data['MaritalStatus'].notna())]['MaritalStatus']

# %%
len(MaritalStatus_mal)
# Out:
# 0

# %%
data['MaritalStatus']
# Out:
# 0            NaN
# 1            NaN
# 2        married
# 3        married
# 4       divorced
#           ...
# 1609     married
# 1610         NaN
# 1611      single
# 1612    divorced
# 1613         NaN
# Name: MaritalStatus, Length: 1614, dtype: object

# %% [markdown]
# **MonthlyIncome**

# %%
MonthlyIncome = data['MonthlyIncome']

# %%
data['MonthlyIncome'] = data['MonthlyIncome'].str.replace(',', '.').astype(float)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1770/2973686824.py in <module>
# ----> 1 data['MonthlyIncome'] = data['MonthlyIncome'].str.replace(',', '.').astype(float)
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     179             # we're accessing the attribute of the class, i.e., Dataset.geo
#     180             return self._accessor
# --> 181         accessor_obj = self._accessor(obj)
#     182         # Replace the property with the accessor object. Inspired by:
# ...

# %%
data['MonthlyIncome']
# Out:
# 0       19537.0
# 1       19999.0
# 2       19232.0
# 3       17169.0
# 4           NaN
#          ...
# 1609    10325.0
# 1610     4447.0
# 1611        NaN
# 1612        NaN
# 1613    10845.0
# Name: MonthlyIncome, Length: 1614, dtype: float64

# %%
MonthlyIncome
# Out:
# 0       19537,0
# 1       19999,0
# 2       19232,0
# 3       17169,0
# 4           NaN
#          ...
# 1609    10325,0
# 1610     4447,0
# 1611        NaN
# 1612        NaN
# 1613    10845,0
# Name: MonthlyIncome, Length: 1614, dtype: object

# %%
MonthlyIncome.describe()
# Out:
# count        771
# unique       668
# top       6347,0
# freq           4
# Name: MonthlyIncome, dtype: object

# %%
MonthlyIncome.sample(10)
# Out:
# 24      6201,0
# 371        NaN
# 1195       NaN
# 1385       NaN
# 785     5321,0
# 837     3929,0
# 611        NaN
# 944     2572,0
# 462     5154,0
# 1427       NaN
# Name: MonthlyIncome, dtype: object

# %%
data['MonthlyIncome'] = data['MonthlyIncome'].str.replace(',', '.').astype(int)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1770/2647425748.py in <module>
# ----> 1 data['MonthlyIncome'] = data['MonthlyIncome'].str.replace(',', '.').astype(int)
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     179             # we're accessing the attribute of the class, i.e., Dataset.geo
#     180             return self._accessor
# --> 181         accessor_obj = self._accessor(obj)
#     182         # Replace the property with the accessor object. Inspired by:
# ...

# %%
#cambiar tipo de dato

data['MonthlyIncome'] = pd.to_numeric(data['MonthlyIncome'], errors='coerce')

# %%
data['MonthlyIncome']
# Out:
# 0       19537.0
# 1       19999.0
# 2       19232.0
# 3       17169.0
# 4           NaN
#          ...
# 1609    10325.0
# 1610     4447.0
# 1611        NaN
# 1612        NaN
# 1613    10845.0
# Name: MonthlyIncome, Length: 1614, dtype: float64

# %%
MonthlyIncome_mal = data[(data['MonthlyIncome'].notna()) & (data['MonthlyIncome'] < 0)]['MonthlyIncome']
#MonthlyIncome_mal = data[(data['MonthlyIncome'].isna())]['MonthlyIncome']

# %%
len(MonthlyIncome_mal)
# Out:
# 0

# %% [markdown]
# **MonthlyRate**

# %%
MonthlyRate = data['MonthlyRate']

# %%
MonthlyRate
# Out:
# 0        6462
# 1        5678
# 2        4933
# 3       26703
# 4        7739
#         ...
# 1609     5518
# 1610    23163
# 1611     2560
# 1612    25952
# 1613    24208
# Name: MonthlyRate, Length: 1614, dtype: int64

# %%
MonthlyRate.describe()
# Out:
# count     1614.000000
# mean     14284.495663
# std       7110.414585
# min       2094.000000
# 25%       8001.000000
# 50%      14248.500000
# 75%      20364.000000
# max      26999.000000
# Name: MonthlyRate, dtype: float64

# %%
MonthlyRate.sample(10)
# Out:
# 1114     2097
# 1543    19100
# 959     16612
# 545     26968
# 439     17000
# 1116    20943
# 337     20978
# 176     10781
# 1017    25308
# 799      8758
# Name: MonthlyRate, dtype: int64

# %%
MonthlyRate_mal = data[(data['MonthlyRate'].isna())]['MonthlyRate']

# %%
len(MonthlyRate_mal)
# Out:
# 0

# %% [markdown]
# **NUMCOMPANIESWORKED**

# %%
#cambiar nombre que no sea en mayúsculas

NumCompaniesWorked = data['NUMCOMPANIESWORKED']

# %%
NumCompaniesWorked.sample(10)
# Out:
# 624     1
# 1277    1
# 167     1
# 1221    1
# 493     7
# 1063    0
# 717     7
# 1394    1
# 162     1
# 1041    0
# Name: NUMCOMPANIESWORKED, dtype: int64

# %%
NumCompaniesWorked.describe()
# Out:
# count    1614.000000
# mean        2.673482
# std         2.506152
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         4.000000
# max         9.000000
# Name: NUMCOMPANIESWORKED, dtype: float64

# %%
NumCompaniesWorked_mal = data[(data['NUMCOMPANIESWORKED'] < 0)]['NUMCOMPANIESWORKED']

NumCompaniesWorked_mal
# Out:
# Series([], Name: NUMCOMPANIESWORKED, dtype: int64)

# %%
len(NumCompaniesWorked_mal)
# Out:
# 0

# %%
data.rename(columns={'NUMCOMPANIESWORKED': 'NumCompaniesWorked'}, inplace=True)

# %%
data.loc[:,'MaritalStatus':'PerformanceRating']
# Out:
#      MaritalStatus  MonthlyIncome  MonthlyRate  NumCompaniesWorked Over18  \
# 0              NaN        19537.0         6462                   7      y
# 1              NaN        19999.0         5678                   0    NaN
# 2          married        19232.0         4933                   1    NaN
# 3          married        17169.0        26703                   3      y
# 4         divorced            NaN         7739                   2      y
# ...            ...            ...          ...                 ...    ...
# 1609       married        10325.0         5518                   1      y
# 1610           NaN         4447.0        23163                   1    NaN
# 1611        single            NaN         2560                   0    NaN
# 1612      divorced            NaN        25952                   4    NaN
# 1613           NaN        10845.0        24208                   6      y
#
#      OverTime  PercentSalaryHike PerformanceRating
# ...

# %% [markdown]
# **Over18**

# %%
data.drop(['Over18'], axis=1, inplace=True)

# %%
data.loc[:,'MaritalStatus':'PerformanceRating']
# Out:
#      MaritalStatus  MonthlyIncome  MonthlyRate  NumCompaniesWorked OverTime  \
# 0              NaN        19537.0         6462                   7       no
# 1              NaN        19999.0         5678                   0      NaN
# 2          married        19232.0         4933                   1       no
# 3          married        17169.0        26703                   3      NaN
# 4         divorced            NaN         7739                   2       no
# ...            ...            ...          ...                 ...      ...
# 1609       married        10325.0         5518                   1      NaN
# 1610           NaN         4447.0        23163                   1      NaN
# 1611        single            NaN         2560                   0       no
# 1612      divorced            NaN        25952                   4       no
# 1613           NaN        10845.0        24208                   6      NaN
#
#       PercentSalaryHike PerformanceRating
# ...

# %%
over18 = data['Over18']
over18.sample(10)
# Out:
# 1356    NaN
# 565       Y
# 207       Y
# 686     NaN
# 1613      Y
# 745     NaN
# 328     NaN
# 599       Y
# 474       Y
# 1464      Y
# Name: Over18, dtype: object

# %%
over18_mal = data[(data['Over18'].isna())]['Over18']
over18_mal
# Out:
# 1       NaN
# 2       NaN
# 5       NaN
# 7       NaN
# 8       NaN
#        ...
# 1607    NaN
# 1608    NaN
# 1610    NaN
# 1611    NaN
# 1612    NaN
# Name: Over18, Length: 901, dtype: object

# %%
data[['Over18', 'DateBirth']]
# Out:
#      Over18  DateBirth
# 0         Y       1972
# 1       NaN       1971
# 2       NaN       1981
# 3         Y       1976
# 4         Y       1977
# ...     ...        ...
# 1609      Y       1987
# 1610    NaN       1978
# 1611    NaN       1984
# 1612    NaN       1987
# 1613      Y       1977
#
# [1614 rows x 2 columns]

# %%
data['DateBirth'].min()
# Out:
# 1963

# %%
data['DateBirth'].max()
# Out:
# 2005

# %% [markdown]
# **OverTime**

# %%
overtime = data['OverTime']
overtime.sample(10)
# Out:
# 88       No
# 1244     No
# 939     NaN
# 859     Yes
# 188      No
# 782      No
# 1390    NaN
# 875     Yes
# 1561     No
# 365     NaN
# Name: OverTime, dtype: object

# %%
overtime_mal = data[(data['OverTime'].isna())]['OverTime']
overtime_mal
# Out:
# 1       NaN
# 3       NaN
# 6       NaN
# 17      NaN
# 18      NaN
#        ...
# 1607    NaN
# 1608    NaN
# 1609    NaN
# 1610    NaN
# 1613    NaN
# Name: OverTime, Length: 676, dtype: object

# %% [markdown]
# **PercentSalaryHike**

# %%
salaryhike = data['PercentSalaryHike']
salaryhike.sample(10)
# Out:
# 628     21
# 1460    12
# 337     11
# 1110    19
# 1326    11
# 714     16
# 883     11
# 593     20
# 603     19
# 1296    23
# Name: PercentSalaryHike, dtype: int64

# %%
salaryhike.describe()
# Out:
# count    1614.000000
# mean       15.165428
# std         3.648610
# min        11.000000
# 25%        12.000000
# 50%        14.000000
# 75%        18.000000
# max        25.000000
# Name: PercentSalaryHike, dtype: float64

# %%
data['PercentSalaryHike'] = data['PercentSalaryHike'].astype(float)

# %% [markdown]
# **PerformanceRating**

# %%
performance = data['PerformanceRating']
performance
# Out:
# 0       3.0
# 1       3.0
# 2       3.0
# 3       3.0
# 4       3.0
#        ...
# 1609    NaN
# 1610    3.0
# 1611    3.0
# 1612    NaN
# 1613    3.0
# Name: PerformanceRating, Length: 1614, dtype: float64

# %%
data['PerformanceRating'] = data['PerformanceRating'].str.replace(',', '.').astype(float)

# %%
performance.describe()
# Out:
# count    1419.00000
# mean        3.15081
# std         0.35799
# min         3.00000
# 25%         3.00000
# 50%         3.00000
# 75%         3.00000
# max         4.00000
# Name: PerformanceRating, dtype: float64

# %%
datos_laura = data.loc[:,'MaritalStatus':'PerformanceRating']

# %%
datos_laura
# Out:
#      MaritalStatus  MonthlyIncome  MonthlyRate  NumCompaniesWorked OverTime  \
# 0              NaN        19537.0         6462                   7       no
# 1              NaN        19999.0         5678                   0      NaN
# 2          married        19232.0         4933                   1       no
# 3          married        17169.0        26703                   3      NaN
# 4         divorced            NaN         7739                   2       no
# ...            ...            ...          ...                 ...      ...
# 1609       married        10325.0         5518                   1      NaN
# 1610           NaN         4447.0        23163                   1      NaN
# 1611        single            NaN         2560                   0       no
# 1612      divorced            NaN        25952                   4       no
# 1613           NaN        10845.0        24208                   6      NaN
#
#       PercentSalaryHike  PerformanceRating
# ...

# %%
datos_laura.to_csv('Files/16_23.csv')
