# %%
import pandas as pd

import numpy as np

# %%
data = pd.read_csv("Files/HR RAW DATA.csv",index_col = 0)

data
# Out:
#      Age Attrition BusinessTravel DailyRate                Department  \
# 0     51        No            NaN    684,0$                       NaN
# 1     52        No            NaN    699,0$                       NaN
# 2     42        No  travel_rarely    532,0$   Research & Development
# 3     47        No  travel_rarely    359,0$                       NaN
# 4     46        No            NaN   1319,0$                       NaN
# ...   ..       ...            ...       ...                       ...
# 1609  36       Yes  travel_rarely    530,0$                       NaN
# 1610  45        No     non-travel    805,0$                       NaN
# 1611  39        No  travel_rarely    903,0$                       NaN
# 1612  36        No     non-travel   1229,0$                       NaN
# 1613  46        No            NaN    566,0$                       NaN
#
#       DistanceFromHome  Education    EducationField  employeecount  \
# ...

# %%
total_ficheros=["Files/1_8.csv","Files/8_15.csv","Files/16_23.csv", "Files/24_32.csv", "Files/33_41.csv"]

# %%
df_completo = pd.concat([pd.read_csv(archivo) for archivo in total_ficheros], ignore_index=False)

# %%
df_completo
# Out:
#       Unnamed: 0   Age Attrition BusinessTravel  DailyRate  \
# 0            0.0  51.0        No            NaN      684.0
# 1            1.0  52.0        No            NaN      699.0
# 2            2.0  42.0        No  travel_rarely      532.0
# 3            3.0  47.0        No  travel_rarely      359.0
# 4            4.0  46.0        No            NaN     1319.0
# ...          ...   ...       ...            ...        ...
# 1609      1609.0   NaN       NaN            NaN        NaN
# 1610      1610.0   NaN       NaN            NaN        NaN
# 1611      1611.0   NaN       NaN            NaN        NaN
# 1612      1612.0   NaN       NaN            NaN        NaN
# 1613      1613.0   NaN       NaN            NaN        NaN
#
#                     Department  DistanceFromHome  Education    EducationField  \
# 0                          NaN               6.0        3.0               NaN
# 1                          NaN               1.0        4.0     life sciences
# ...

# %%
df_completo.tail()
# Out:
#       Unnamed: 0  Age Attrition BusinessTravel  DailyRate Department  \
# 1609      1609.0  NaN       NaN            NaN        NaN        NaN
# 1610      1610.0  NaN       NaN            NaN        NaN        NaN
# 1611      1611.0  NaN       NaN            NaN        NaN        NaN
# 1612      1612.0  NaN       NaN            NaN        NaN        NaN
# 1613      1613.0  NaN       NaN            NaN        NaN        NaN
#
#       DistanceFromHome  Education EducationField  age  ... MonthlyIncome  \
# 1609               NaN        NaN            NaN  NaN  ...           NaN
# 1610               NaN        NaN            NaN  NaN  ...           NaN
# 1611               NaN        NaN            NaN  NaN  ...           NaN
# 1612               NaN        NaN            NaN  NaN  ...           NaN
# 1613               NaN        NaN            NaN  NaN  ...           NaN
#
#      MonthlyRate NumCompaniesWorked OverTime  PercentSalaryHike  \
# ...

# %%
data_total=[]
for archivo in total_ficheros:
    df = pd.read_csv(archivo)
    data_total.append(df)

# %%
total_archivo=pd.DataFrame(data_total)
# Out:
# /home/lauragenesis/anaconda3/lib/python3.9/site-packages/pandas/core/internals/construction.py:540: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   values = np.array([convert(v) for v in values])

# %%
total_archivo
# Out:
#                                                    0
# 0        Unnamed: 0  Age Attrition BusinessTravel...
# 1       age attrition businesstravel dailyrate   ...
# 2        Unnamed: 0 MaritalStatus  MonthlyIncome ...
# 3        Unnamed: 0  relationshipsatisfaction  st...
# 4        Unnamed: 0  YearsSinceLastPromotion  YEA...

# %%
#Leemos todos los archivos limpiados 

tabla_total = pd.read_csv()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 #Leemos todos los archivos limpiados
# ----> 2 tabla_total = pd.read_csv(["1_8.csv","8_15.csv","16_23.csv", "24_32.csv", "33_41.csv"])
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
#Unimos con el concant quitando los indices
tabla_total = pd.concat([], axis=1, ignore_index = True)

# %%
#Cambiamos las columnas de todas 
tabla_total.columns = [columna.Capita() for columna in columnas]
print(data.columns)
