# %%
# importamos las librerías que necesitamos

# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np

# Visualización
# ------------------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns

# Evaluar linealidad de las relaciones entre las variables
# y la distribución de las variables
# ------------------------------------------------------------------------------
import scipy.stats as stats
from scipy.stats import shapiro, poisson, chisquare, expon, kstest,chi2_contingency,ttest_ind

# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# Gestión de los warnings
# -----------------------------------------------------------------------
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("Files/data_final.csv",index_col=0)

# %%
df.sample(20)
# Out:
#      Attrition     Businesstravel  Dailyrate  Distancefromhome  Education  \
# 1336       yes  travel frequently      781.0                 2          1
# 572         no      travel rarely     1268.0                 4          2
# 1120        no            unknown      661.0                31          4
# 367         no         non-travel      805.0                47          2
# 745         no  travel frequently      322.0                28          2
# 484         no      travel rarely      613.0                 6          1
# 203         no            unknown      430.0                24          4
# 1082        no            unknown      634.0                 5          4
# 481         no      travel rarely      582.0                28          4
# 1353       yes            unknown     1097.0                16          3
# 218        yes            unknown      408.0                23          1
# 120         no            unknown      672.0                 7          2
# 1162        no      travel rarely      529.0                 2          3
# 1117        no            unknown     1054.0                48          3
# 650         no  travel frequently      163.0                24          1
# 458        yes            unknown      303.0                27          3
# 869         no  travel frequently      444.0                 5          3
# 1560        no      travel rarely     1178.0                31          2
# 388        yes  travel frequently      203.0                 2          3
# 588         no      travel rarely      759.0                 2          2
#
#         Educationfield  Employeenumber  Environmentsatisfaction Gender  \
# 1336           unknown             918                        4      H
# 572            unknown             240                        3      M
# 1120           unknown               0                        1      M
# 367            unknown             972                       47      H
# 745            unknown            1401                        4      M
# 484            unknown            2062                        4      H
# 203      life sciences             772                        1      H
# 1082           unknown            1607                        2      M
# 481      life sciences            2034                        1      M
# 1353           medical               0                        4      M
# 218            unknown               0                        4      M
# 120            unknown             444                        3      H
# 1162  technical degree            2038                        4      H
# 1117           unknown            1751                       48      M
# 650   technical degree            1736                        4      M
# 458            unknown            1797                        3      H
# 869            unknown               0                        4      M
# 1560           unknown             500                       31      M
# 388      life sciences               0                        1      H
# 588          marketing               0                        4      M
#
#       Hourlyrate  Jobinvolvement  Joblevel                      Jobrole  \
# 1336        57.0               2         1       laboratory technician
# 572         30.0               3         2             sales executive
# 1120        60.0               2         4      manufacturing director
# 367         57.0               3         2       laboratory technician
# 745         59.0               4         4      manufacturing director
# 484         42.0               2         3   healthcare representative
# 203         80.0               3         2       laboratory technician
# 1082        35.0               4         1          research scientist
# 481         60.0               2         4      manufacturing director
# 1353        98.0               2         1          research scientist
# 218         45.0               2         3             sales executive
# 120         54.0               2         5                     manager
# 1162        78.0               3         1          research scientist
# 1117        67.0               3         1          research scientist
# 650         30.0               3         2      manufacturing director
# 458         84.0               3         2             sales executive
# 869         84.0               3         1        sales representative
# 1560        87.0               3         2             sales executive
# 388         84.0               3         4   healthcare representative
# 588         46.0               3         2             sales executive
#
#       Jobsatisfaction Maritalstatus  Monthlyrate  Numcompaniesworked Overtime  \
# 1336                4      divorced        13384                   9  unknown
# 572                 1       unknown         6319                   4  unknown
# 1120                3       married        22308                   4      yes
# 367                 2       unknown        23163                   1  unknown
# 745                 3       married         9731                   2  unknown
# 484                 1       unknown        21457                   4  unknown
# 203                 4       unknown        21146                   1       no
# 1082                4       married        18783                   3       no
# 481                 2       married         5640                   0       no
# 1353                1       unknown        18275                   1      yes
# 218                 1       unknown        11162                   1  unknown
# 120                 4       married        21141                   1  unknown
# 1162                1       unknown        11288                   1       no
# 1117                4       unknown         6152                   1  unknown
# 650                 4        single         6670                   2  unknown
# 458                 4       unknown        13492                   1  unknown
# 869                 2      divorced         3909                   1  unknown
# 1560                4       unknown        14862                   4       no
# 388                 4       unknown        13547                   7       no
# 588                 2      divorced        22553                   7  unknown
#
#       Percentsalaryhike  Performancerating  Relationshipsatisfaction  \
# 1336                 14                  3                         4
# 572                  11                  3                         1
# 1120                 20                  4                         4
# 367                  12                  3                         2
# 745                  11                  3                         2
# 484                  15                  3                         1
# 203                  15                  0                         4
# 1082                 17                  3                         4
# 481                  23                  0                         3
# 1353                 15                  3                         1
# 218                  13                  0                         1
# 120                  15                  3                         1
# 1162                 14                  3                         4
# 1117                 11                  3                         3
# 650                  20                  4                         4
# 458                  18                  3                         4
# 869                  11                  3                         3
# 1560                 11                  3                         3
# 388                  11                  3                         4
# 588                  12                  3                         3
#
#       Stockoptionlevel  Totalworkingyears  Trainingtimeslastyear  \
# 1336                 1                  3                      3
# 572                  1                  9                      3
# 1120                 3                 27                      2
# 367                  0                  0                      5
# 745                  1                  0                      3
# 484                  1                  0                      5
# 203                  2                 10                      2
# 1082                 2                  6                      3
# 481                  1                 21                      3
# 1353                 0                  1                      2
# 218                  1                 11                      3
# 120                  1                  0                      2
# 1162                 0                  0                      4
# 1117                 0                  6                      5
# 650                  0                  9                      3
# 458                  0                  0                      2
# 869                  1                  2                      5
# 1560                 1                 18                      2
# 388                  3                 21                      4
# 588                  2                  0                      5
#
#       Worklifebalance  Yearsatcompany  Yearsincurrentrole  \
# 1336                2               1                   0
# 572                 4               5                   0
# 1120                2               3                   0
# 367                 2               9                   0
# 745                 2               5                   0
# 484                 3               7                   0
# 203                 3              10                   0
# 1082                3               3                   0
# 481                 3              20                   0
# 1353                3               1                   0
# 218                 1              11                   0
# 120                 3              21                   0
# 1162                3               4                   0
# 1117                2               6                   0
# 650                 2               5                   0
# 458                 3              10                   0
# 869                 2               2                   0
# 1560                2               7                   0
# 388                 3              18                   0
# 588                 3               5                   0
#
#       Yearssincelastpromotion  Yearswithcurrmanager  Datebirth Remotework  \
# 1336                        0                     0       1965        yes
# 572                         0                     3       1978         no
# 1120                        0                     2       1970        yes
# 367                         0                     8       1978        yes
# 745                         0                     2       1971        yes
# 484                         1                     7       1984        yes
# 203                         4                     7       1991    unknown
# 1082                        0                     2       1991        yes
# 481                         0                    10       1982    unknown
# 1353                        0                     0       2003         no
# 218                         3                    10       1994        yes
# 120                        13                     3       1984        yes
# 1162                        1                     2       1991        yes
# 1117                        1                     4       1996         no
# 650                         1                     4       1992    unknown
# 458                         7                     7       1988         no
# 869                         2                     2       1992        yes
# 1560                        0                     7       1972         no
# 388                        11                     5       1984         no
# 588                         1                     3       1983        yes
#
#       Employee_id
# 1336          918
# 572           240
# 1120         5789
# 367           972
# 745          1401
# 484          2062
# 203           772
# 1082         1607
# 481          2034
# 1353         6702
# 218          8501
# 120           444
# 1162         2038
# 1117         1751
# 650          1736
# 458          1797
# 869          4488
# 1560        16718
# 388          2002
# 588         13984

# %% [markdown]
# **Establecer hipótesis**

# %% [markdown]
# **Hipótesis nula**[HO]: No hay cambios significativos entre los dos grupos
#
# **Hipótesis alternativa**[H1]: Hay cambios significativos entre lso dos grupos

# %% [markdown]
# Se sospecha que los empleados con niveles de satisfacción más bajos tienen una mayor probabilidad de dejar la empresa.
#
# **Grupos**
#
# - Control: Empleados con un nivel de satisfacción en el trabajo igual o superior a 3 en una escala de 1 a 5
# - Variante: Empleados con un nivel de satisfacción en el trabajo inferior a 3 en la misma escala
#
# **Métrica**
#
# - Attrition:
#
# No: empleado no ha dejado la empresa
#
# Yes: empleado ha dejado la empresa

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'Businesstravel', 'Dailyrate', 'Distancefromhome',
#        'Education', 'Educationfield', 'Environmentsatisfaction', 'Gender',
#        'Hourlyrate', 'Jobinvolvement', 'Joblevel', 'Jobrole',
#        'Jobsatisfaction', 'Maritalstatus', 'Monthlyrate', 'Numcompaniesworked',
#        'Overtime', 'Percentsalaryhike', 'Performancerating',
#        'Relationshipsatisfaction', 'Stockoptionlevel', 'Trainingtimeslastyear',
#        'Worklifebalance', 'Yearsatcompany', 'Yearssincelastpromotion',
#        'Yearswithcurrmanager', 'Datebirth', 'Remotework'],
#       dtype='object')

# %%
# Paso1. Dividimos a los empleados en los grupos A y B 

def asignar_grupos(numero):
    if numero >= 3:
        return "grupo A"
    else:
        return "grupo B"
    

df["Jobsatisfaction_ab"]= df["Jobsatisfaction"].apply(asignar_grupos)
df["Environmentsatisfactionab"]=df["Environmentsatisfaction"].apply(asignar_grupos)
df["Relationshipsatisfaction_ab"]=df["Relationshipsatisfaction"].apply(asignar_grupos)
df["Jobinvolvement_ab"]=df["Jobinvolvement"].apply(asignar_grupos)
df["Worklifebalance_ab"]=df["Worklifebalance"].apply(asignar_grupos)

# %%
# Calculamos de la tasa de rotación

df_rotacion = df[df["Attrition"] == "Yes"]
tasa_rotacion = df.shape[0] / df.shape[0]
print(f"la tasa de rotación del grupo de control es:{tasa_rotacion}")

# Tasa de rotación en grupo variante
df_variante_rotacion = df[df["Attrition"] == "Yes"]
tasa_rotacion_variante = df_variante_rotacion.shape[0] / df.shape[0]
print(f"la tasa de rotación del grupo variante es:{tasa_rotacion_variante}")
# Out:
# la tasa de rotación del grupo de control es:1.0
# la tasa de rotación del grupo variante es:0.15952080706179067

# %%
# Gráfico para visualizar la diferencia en la tasa de rotación

# Tasa de conversión
rota = {"grupo":["control", "variante"], "tasa_rotacion": [0.14, 0.2]}
df_rotacion = pd.DataFrame(rota)

# Gráfica de rotacion
sns.barplot(x="grupo", y="tasa_rotacion", data=df_rotacion)
plt.title("Tasa de rotación");

# %% [markdown]
# La tasa de rotación es mayor en el grupo variante (satisfacción bajo)

# %%
# Tabla de contingencia
contingency_table = pd.crosstab(df["Jobsatisfaction_ab"], df['Attrition'])

# Realizar la prueba de proporciones
chi2, p_value, _, _ = chi2_contingency(contingency_table)
print(p_value)

# Imprimir resultado 
alpha = 0.05
if p_value < alpha:
    print("Hay una diferencia significativa en la tasa de rotación de ambos grupos.")
    print("\n ---------- \n")
    print("""
          Los resultados sugieren que si que existe una diferencia entre los grupos 
          """)
else:
    print("No hay evidencia de una diferencia significativa en la tasa de rotación de ambos grupos.")
    print("\n ---------- \n")
    print(""" 
          Los resultados sugieren que no existe evidencia estadística para afirmar que las medias de las muestras son distintas
          """)
# Out:
# 0.0035330175381607944
# Hay una diferencia significativa en la tasa de rotación de ambos grupos.
#
#  ----------
#
#
#           Los resultados sugieren que si que existe una diferencia entre los grupos

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 5),sharey=True)



# Gráfico 1: Rotación del grupo control
sns.countplot(x="Jobsatisfaction_ab", hue="Attrition", data=df, ax=axes[0])
axes[0].set_title("Rotación grupo control")

# Gráfico 2: Rotación del grupo variante
sns.countplot(x="Jobsatisfaction_ab", hue="Attrition", data=df, ax=axes[1])
axes[1].set_title("Rotación grupo variante");

# %% [markdown]
# **Análisis estadístico para:**
#
# Verificar:
# - Normalidad
# - Homogeneidad de Varianzas
# - Independencia

# %%
df['Attrition'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
# Convertir "Sí" a 1 y "No" a 0
df["Attrition_numeric"] = df["Attrition"].map({"Yes": 1, "No": 0})

# Verificar si la conversión fue exitosa
print(df["Attrition_numeric"].head())
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Attrition_numeric, dtype: int64

# %%
# NORMALIDAD (Shapiro)

def normalidad(dataframe, columna):
    if dataframe[columna].dtype != "object":
        statistic, p_value = stats.shapiro(dataframe[columna])
        if p_value > 0.05:
            print(f"Para la columna {columna} los datos siguen una distribución normal.")
        else:
         print(f"Para la columna {columna} los datos no siguen una distribución normal.")
    else:
        print(f"La columna {columna} no contiene datos numéricos, no se puede realizar el test de normalidad.")

normalidad(df, "Attrition_numeric")
# Out:
# Para la columna Attrition_numeric los datos no siguen una distribución normal.

# %% [markdown]
# Si 'attrition' no sigue una distribución normal, tendríamos que hacer la prueba de ManWhitney

# %%
cross_tab = pd.crosstab(df["Attrition"],df["Jobsatisfaction_ab"])
cross_tab
# Out:
# Jobsatisfaction_ab  grupo A  grupo B
# Attrition
# No                      839      494
# Yes                     134      119

# %% [markdown]
# **HO**: No existe relación entre la satisfacción y la continuidad en la empresa.
#
#
# **H1**: Existe relación entre la satisfacción y la continuidad en la empresa.

# %%
chi2, p_value, _, _ = chi2_contingency(cross_tab)

alpha = 0.05
if p_value < alpha:
    print("Hay una diferencia significativa entre la satisfacción y la continuidad en la empresa")
    print("\n ---------- \n")
    
else:
    print("No hay evidencia de una diferencia significativa entre la continuidad en la empresa y la satisfacción")
    print("\n ---------- \n")
# Out:
# Hay una diferencia significativa entre la satisfacción y la continuidad en la empresa
#
#  ----------

# %% [markdown]
# < 0.05 Rechazamos hipótesis nula, hay diferencia en la tasa de conversión entre los grupos AD y PSA
# > 0.05 Aceptamos  la hipótesis nula, no hay diferencia en la tasa de conversión

# %%
sns.barplot(x="Jobsatisfaction_ab", y="Attrition_numeric", data=df,  palette = "plasma");
plt.xlabel('Satisfacción')
plt.ylabel('Continuidad')
plt.title('Satisfacción vs continuidad', fontsize = 10);

# %%
df.columns
# Out:
# Index(['Attrition', 'Businesstravel', 'Dailyrate', 'Distancefromhome',
#        'Education', 'Educationfield', 'Employeenumber',
#        'Environmentsatisfaction', 'Gender', 'Hourlyrate', 'Jobinvolvement',
#        'Joblevel', 'Jobrole', 'Jobsatisfaction', 'Maritalstatus',
#        'Monthlyrate', 'Numcompaniesworked', 'Overtime', 'Percentsalaryhike',
#        'Performancerating', 'Relationshipsatisfaction', 'Stockoptionlevel',
#        'Totalworkingyears', 'Trainingtimeslastyear', 'Worklifebalance',
#        'Yearsatcompany', 'Yearsincurrentrole', 'Yearssincelastpromotion',
#        'Yearswithcurrmanager', 'Datebirth', 'Remotework', 'Employee_id'],
#       dtype='object')

# %%
analisis_trabajador= df.loc[:, ["Environmentsatisfaction", "Gender"]].reset_index(drop=True)
analisis_trabajador.sample(30)
# Out:
#       Environmentsatisfaction Gender
# 95                          2      M
# 600                         2      H
# 40                          3      M
# 1254                        4      H
# 127                         2      H
# 947                        25      M
# 754                         4      H
# 1167                        3      H
# 880                         3      H
# 1214                        4      M
# 1195                       46      H
# 1440                        3      H
# 1101                        2      M
# 992                        20      H
# 625                         1      H
# 182                         2      H
# 631                        47      H
# 626                         3      H
# 904                         3      M
# 412                         1      H
# 431                         1      H
# 1112                        2      H
# 955                         2      H
# 53                          1      M
# 1070                        3      H
# 1261                        2      H
# 1578                        3      M
# 1271                        1      H
# 1449                        4      H
# 81                          4      M

# %%
genero_satisfaccion = df.groupby(['Environmentsatisfaction', 'Gender']).size().reset_index(name='Count')
genero_satisfaccion
# Out:
#     Environmentsatisfaction Gender  Count
# 0                         1      H    177
# 1                         1      M    117
# 2                         2      H    176
# 3                         2      M    118
# 4                         3      H    269
# ..                      ...    ...    ...
# 58                       47      H      3
# 59                       47      M      2
# 60                       48      H      1
# 61                       48      M      3
# 62                       49      H      1
#
# [63 rows x 3 columns]

# %%
genero_satisfaccion = df.groupby(['Environmentsatisfaction', 'Gender']).size().reset_index(name='Count')

# Crear el gráfico de barras
plt.figure(figsize=(12, 8))
sns.barplot(x='Environmentsatisfaction', y='Count', hue='Gender', data=genero_satisfaccion)
plt.title('Relación entre Satisfacción laboral y Género')
plt.xlabel('Nivel de satisfacción laboral')
plt.ylabel('Cantidad')
plt.xticks(rotation=45)  # Rotar las etiquetas del eje x para mayor legibilidad
plt.grid(True, axis='y', linestyle='--', alpha=0.7)  # Añadir líneas de grid en el eje y
plt.legend(title='Género')
plt.tight_layout()  # Ajustar el diseño para evitar que se superpongan los elementos
plt.show()

# %%
niveles=  {1: 'bajo', 2: 'medio', 3: 'alto', 4: 'máximo'}
def assing_labels(row):
    if int(row['Environmentsatisfaction']) in niveles:
        
        row['labels'] = niveles[row['Environmentsatisfaction']]
    else:
        row['labels'] = ""
    return row
genero_satisfaccion = genero_satisfaccion.apply(assing_labels, axis=1)
genero_satisfaccion
# Out:
#     Environmentsatisfaction Gender  Count labels
# 0                         1      H    177   bajo
# 1                         1      M    117   bajo
# 2                         2      H    176  medio
# 3                         2      M    118  medio
# 4                         3      H    269   alto
# ..                      ...    ...    ...    ...
# 58                       47      H      3
# 59                       47      M      2
# 60                       48      H      1
# 61                       48      M      3
# 62                       49      H      1
#
# [63 rows x 4 columns]

# %%
# niveles=  {1: 'bajo', 2: 'medio', 3: 'alto', 4: 'máximo'}
# genero_satisfaccion['Environmentsatisfaction'] = genero_satisfaccion['Environmentsatisfaction'].map(niveles)

# genero_satisfaccion = df.groupby(['Environmentsatisfaction', 'Gender']).size().reset_index(name='Count')
# genero_satisfaccion

plt.figure(figsize=(10, 6))
sns.barplot(x='labels', y='Count', hue='Gender', data=genero_satisfaccion , )
plt.title('Relación entre Satisfacción laboral y Género')
plt.xlabel('Satisfacción laboral')
plt.ylabel('Cantidad')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[91], line 8
#       1 # niveles=  {1: 'bajo', 2: 'medio', 3: 'alto', 4: 'máximo'}
#       2 # genero_satisfaccion['Environmentsatisfaction'] = genero_satisfaccion['Environmentsatisfaction'].map(niveles)
#       3
#       4 # genero_satisfaccion = df.groupby(['Environmentsatisfaction', 'Gender']).size().reset_index(name='Count')
#       5 # genero_satisfaccion
#       7 plt.figure(figsize=(10, 6))
# ----> 8 sns.barplot(x='labels', y='Count', hue='Gender', data=genero_satisfaccion , color="pink")
#       9 plt.title('Relación entre Satisfacción laboral y Género')
#      10 plt.xlabel('Satisfacción laboral')
#
# File ~/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:3182, in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3169 @_deprecate_positional_args
#    3170 def barplot(
#    3171     *,
#    (...)
#    3179     **kwargs,
#    3180 ):
# -> 3182     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    3183                           estimator, ci, n_boot, units, seed,
#    3184                           orient, color, palette, saturation,
#    3185                           errcolor, errwidth, capsize, dodge)
#    3187     if ax is None:
#    3188         ax = plt.gca()
#
# File ~/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:1584, in _BarPlotter.__init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1579 def __init__(self, x, y, hue, data, order, hue_order,
#    1580              estimator, ci, n_boot, units, seed,
#    1581              orient, color, palette, saturation, errcolor,
#    1582              errwidth, capsize, dodge):
#    1583     """Initialize the plotter."""
# -> 1584     self.establish_variables(x, y, hue, data, orient,
#    1585                              order, hue_order, units)
#    1586     self.establish_colors(color, palette, saturation)
#    1587     self.estimate_statistic(estimator, ci, n_boot, seed)
#
# File ~/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:153, in _CategoricalPlotter.establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     151     if isinstance(var, str):
#     152         err = "Could not interpret input '{}'".format(var)
# --> 153         raise ValueError(err)
#     155 # Figure out the plotting orientation
#     156 orient = infer_orient(
#     157     x, y, orient, require_numeric=self.require_numeric
#     158 )
#
# ValueError: Could not interpret input 'labels'

# %%
df["Jobinvolvement"].unique()
# Out:
# array([3, 2, 4, 1])

# %%
genero_satisfaccion = df.groupby(['Jobinvolvement', 'Gender']).size().reset_index(name='Count')
genero_satisfaccion
# Out:
#    Jobinvolvement Gender  Count
# 0               1      H     55
# 1               1      M     33
# 2               2      H    233
# 3               2      M    168
# 4               3      H    566
# 5               3      M    369
# 6               4      H    100
# 7               4      M     62

# %%
genero_satisfaccion = df.groupby(['Jobinvolvement', 'Gender']).size().reset_index(name='Count')

# Crear el gráfico de barras
plt.figure(figsize=(10, 6))
sns.barplot(x='Jobinvolvement', y='Count', hue='Gender', data=genero_satisfaccion)
plt.title('Distribución de Jobinvolvement por Género')
plt.xlabel('Jobinvolvement')
plt.ylabel('Cantidad')
plt.legend(title='Género')
plt.show()
